# %%
import pandas as pd
jobgender = pd.read_csv("jobs_gender.csv")

# %%
jobgender
# Out:
#       year                                 occupation  \
# 0     2013                           Chief executives
# 1     2013            General and operations managers
# 2     2013                                Legislators
# 3     2013        Advertising and promotions managers
# 4     2013               Marketing and sales managers
# ...    ...                                        ...
# 2083  2016                  Pumping station operators
# 2084  2016  Refuse and recyclable material collectors
# 2085  2016                 Mine shuttle car operators
# 2086  2016          Tank car, truck, and ship loaders
# 2087  2016         Material moving workers, all other
#
#                                        major_category   minor_category  \
# 0                 Management, Business, and Financial       Management
# 1                 Management, Business, and Financial       Management
# 2                 Management, Business, and Financial       Management
# ...

# %%
(jobgender.head(10))
# Out:
#    year                                 occupation  \
# 0  2013                           Chief executives
# 1  2013            General and operations managers
# 2  2013                                Legislators
# 3  2013        Advertising and promotions managers
# 4  2013               Marketing and sales managers
# 5  2013  Public relations and fundraising managers
# 6  2013           Administrative services managers
# 7  2013  Computer and information systems managers
# 8  2013                         Financial managers
# 9  2013         Compensation and benefits managers
#
#                         major_category minor_category  total_workers  \
# 0  Management, Business, and Financial     Management        1024259
# 1  Management, Business, and Financial     Management         977284
# 2  Management, Business, and Financial     Management          14815
# 3  Management, Business, and Financial     Management          43015
# ...

# %%
(jobgender.info(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2088 entries, 0 to 2087
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   2088 non-null   int64
#  1   occupation             2088 non-null   object
#  2   major_category         2088 non-null   object
#  3   minor_category         2088 non-null   object
#  4   total_workers          2088 non-null   int64
#  5   workers_male           2088 non-null   int64
#  6   workers_female         2088 non-null   int64
#  7   percent_female         2088 non-null   float64
#  8   total_earnings         2088 non-null   int64
#  9   total_earnings_male    2084 non-null   float64
#  10  total_earnings_female  2023 non-null   float64
#  11  wage_percent_of_male   1242 non-null   float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 195.9+ KB

# %%
jobgender.describe()
# Out:
#               year  total_workers  workers_male  workers_female  \
# count  2088.000000   2.088000e+03  2.088000e+03    2.088000e+03
# mean   2014.500000   1.960549e+05  1.115154e+05    8.453951e+04
# std       1.118302   3.753610e+05  2.331544e+05    2.126960e+05
# min    2013.000000   6.580000e+02  0.000000e+00    0.000000e+00
# 25%    2013.750000   1.868700e+04  1.076475e+04    2.364500e+03
# 50%    2014.500000   5.899700e+04  3.230150e+04    1.523850e+04
# 75%    2015.250000   1.874152e+05  1.026438e+05    6.332650e+04
# max    2016.000000   3.758629e+06  2.570385e+06    2.290818e+06
#
#        percent_female  total_earnings  total_earnings_male  \
# count     2088.000000     2088.000000           2084.00000
# mean        35.999711    49762.093391          53138.06190
# std         27.492677    22926.685111          24765.75765
# min          0.000000    17266.000000          12147.00000
# 25%         10.729169    32410.000000          35701.50000
# ...

# %%
jobgender.shape
# Out:
# (2088, 12)

# %%
jobgender.sum()
# Out:
# year                                                               4206276
# occupation               Chief executivesGeneral and operations manager...
# major_category           Management, Business, and FinancialManagement,...
# minor_category           ManagementManagementManagementManagementManage...
# total_workers                                                    409362561
# workers_male                                                     232844062
# workers_female                                                   176518499
# percent_female                                                75167.396694
# total_earnings                                                   103903251
# total_earnings_male                                            110739721.0
# total_earnings_female                                           90389735.0
# wage_percent_of_male                                         104367.551532
# dtype: object

# %%
jobgender.isna()
# Out:
#        year  occupation  major_category  minor_category  total_workers  \
# 0     False       False           False           False          False
# 1     False       False           False           False          False
# 2     False       False           False           False          False
# 3     False       False           False           False          False
# 4     False       False           False           False          False
# ...     ...         ...             ...             ...            ...
# 2083  False       False           False           False          False
# 2084  False       False           False           False          False
# 2085  False       False           False           False          False
# 2086  False       False           False           False          False
# 2087  False       False           False           False          False
#
#       workers_male  workers_female  percent_female  total_earnings  \
# ...

# %% [markdown]
# -Occupation with the largest total workers
# -Occupation gender comparision
# -Year with least total workers

# %%
jobs_2013=jobgender[jobgender['year']==2013]

# %%
jobs_2013
# Out:
#      year                                 occupation  \
# 0    2013                           Chief executives
# 1    2013            General and operations managers
# 2    2013                                Legislators
# 3    2013        Advertising and promotions managers
# 4    2013               Marketing and sales managers
# ..    ...                                        ...
# 517  2013                  Pumping station operators
# 518  2013  Refuse and recyclable material collectors
# 519  2013                 Mine shuttle car operators
# 520  2013          Tank car, truck, and ship loaders
# 521  2013         Material moving workers, all other
#
#                                       major_category   minor_category  \
# 0                Management, Business, and Financial       Management
# 1                Management, Business, and Financial       Management
# 2                Management, Business, and Financial       Management
# ...

# %%
jobs_2013.describe()
# Out:
#          year  total_workers  workers_male  workers_female  percent_female  \
# count   522.0   5.220000e+02  5.220000e+02    5.220000e+02      522.000000
# mean   2013.0   1.893636e+05  1.076401e+05    8.172347e+04       35.688506
# std       0.0   3.599502e+05  2.209055e+05    2.088239e+05       27.528694
# min    2013.0   8.360000e+02  0.000000e+00    0.000000e+00        0.000000
# 25%    2013.0   1.909950e+04  1.029325e+04    2.286250e+03       10.300000
# 50%    2013.0   5.861100e+04  3.203450e+04    1.506350e+04       31.250000
# 75%    2013.0   1.847285e+05  9.836400e+04    6.302850e+04       56.950000
# max    2013.0   3.034121e+06  2.365886e+06    2.290818e+06      100.000000
#
#        total_earnings  total_earnings_male  total_earnings_female  \
# count      522.000000           521.000000             506.000000
# mean     48584.316092         51920.886756           43585.778656
# std      22133.718077         23958.944897           20909.597084
# ...

# %%
sum(jobs_2013['total_workers'])
# Out:
# 98847786

# %%
jobs_2014=jobgender[jobgender['year']==2014]

# %%
jobs_2014
sum(jobs_2014['total_workers'])
# Out:
# 101201252

# %%
jobs_2015=jobgender[jobgender['year']==2015]
jobs_2015
sum(jobs_2015['total_workers'])
# Out:
# 103713445

# %%
jobs_2016=jobgender[jobgender['year']==2016]
jobs_2016
sum(jobs_2016['total_workers'])
# Out:
# 105600078

# %%
jobs_2013total=[sum(jobs_2013['total_workers'])]

# %%
jobs_2013total
# Out:
# [98847786]

# %%
jobs_2014total=sum(jobs_2014['total_workers'])

# %%
jobs_2014total
# Out:
# 101201252

# %%
jobs_2015total=sum(jobs_2015['total_workers'])

# %%
jobs_2015total
# Out:
# 103713445

# %%
jobs_2016total=sum(jobs_2016['total_workers'])

# %%
jobs_2016total
# Out:
# 105600078
